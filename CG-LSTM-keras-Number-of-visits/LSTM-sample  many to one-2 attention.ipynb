# %%
import pandas as pd
from datetime import datetime
from pandas import DataFrame
from pandas import Series
from pandas import concat
from pandas import read_csv
from pandas import datetime
from sklearn.preprocessing import MinMaxScaler
from math import sqrt
import matplotlib
from matplotlib import pyplot
import numpy as np
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import sklearn
import keras
from sklearn.metrics import mean_squared_error
from tensorflow.keras import Input
from tensorflow.keras.layers import Dense, LSTM, Dropout, Bidirectional
from tensorflow.keras.models import load_model, Model
from attention import Attention
print('Scikit-Learn:',sklearn.__version__)
print('Keras:',keras.__version__)
print('Numpy:',np.__version__)
print('Pandas:',pd.__version__)
print('Matplotlib:',matplotlib.__version__)
# Out:
# Scikit-Learn: 0.24.1
# Keras: 2.4.3
# Numpy: 1.19.2
# Pandas: 1.1.5
# Matplotlib: 3.3.4

# %% [markdown]
# # LSTM Model Many to One (Attention)
# # Environment Package:
# # Numpy, Keras(Tensorflow), Scikit-Learn, Pandas, Matplotlib,
# # Attention(API)↓
# # https://github.com/philipperemy/keras-attention-mechanism

# %%
print('env pass')
# Out:
# env pass

# %%
n_features = 1
n_steps = 30
df = read_csv('Linkou3.csv')
df_n = np.array([[i[1]] for i in df.values])
date_df = np.array([[i[0]] for i in df.values])
scaler = MinMaxScaler(feature_range=(0, 1))
df_n = scaler.fit_transform(df_n)

# %%
def split_sequence(sequence, n_steps):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the sequence
		if end_ix > len(sequence)-1:
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return np.array(X), np.array(y)

# %%
# data subgroup train = train_len, test = total - train_len
train_len = len([i for i in date_df.flatten() if ('/2015' in i)!=True])
Train_sub = df_n[:train_len]
Test_sub = df_n[train_len:]
X_T, y_T = split_sequence(Train_sub, 30)
X_t, y_t = split_sequence(Test_sub, 30)
print('Total Len = ',len(date_df.flatten()) ,'  Train Len = ',len(Train_sub), '  Test Len = ',len(Test_sub))
# Out:
# Total Len =  2996   Train Len =  2641   Test Len =  355

# %%
def model_class(model_name, X_T, y_T, X_t, y_t, units, att_status):
    model_input = Input(shape=(n_steps, n_features))
    if 'base' in model_name:
        x = LSTM(units, activation='tanh', return_sequences=att_status)(model_input)
        if att_status==True:
            x = Attention()(x)

    elif 'stack' in model_name:
        x = LSTM(units, activation='tanh', return_sequences=True)(model_input)
        x = LSTM(units//2, activation='tanh', return_sequences=att_status)(x)
        if att_status==True:
            x = Attention()(x)
    elif 'bidirect' in model_name:
        x = Bidirectional(LSTM(units, activation='tanh', return_sequences=att_status))(model_input)
        
        if att_status==True:
            x = LSTM(units//2, activation='tanh', return_sequences=True)(x)
            x = Attention()(x)

    x = Dense(1)(x)
    model = Model(model_input, x)
    model.compile(optimizer='adam', loss='mean_squared_error')
    model.summary()
    print(f'----------start train {model_name}----------')
    history = model.fit(X_T, y_T, epochs=50, validation_data=(X_t, y_t), verbose=0)
    print(f'----------start test {model_name}----------')
    trainPred = model.predict(X_T)
    testPred = model.predict(X_t)
    
    return history, trainPred, testPred

# %%
model_list = ['base lstm', 'stack lstm', 'bidirect lstm', 'base lstm attention', 'stack lstm attention', 'bidirect lstm attention']
# model_list = ['bidirect lstm attention']
train_pred_list=[]
test_pred_list=[]
histroy_list=[]
for i in model_list:
    att_status = False
    # model_class def function = (model name, train data, train label, test data, test label, units number)
    if 'attention' in i:
        att_status = True
    history, trainPred, testPred = model_class(i, X_T, y_T, X_t, y_t, 100, att_status)
    train_pred_list.append(trainPred)
    test_pred_list.append(testPred)
    histroy_list.append(history)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 30, 1)]           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 100)               40800
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 40,901
# Trainable params: 40,901
# Non-trainable params: 0
# _________________________________________________________________
# ----------start train base lstm----------
# ----------start test base lstm----------
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 30, 1)]           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30, 100)           40800
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                30200
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________
# ----------start train stack lstm----------
# ----------start test stack lstm----------
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 30, 1)]           0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 200)               81600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 201
# =================================================================
# Total params: 81,801
# Trainable params: 81,801
# Non-trainable params: 0
# _________________________________________________________________
# ----------start train bidirect lstm----------
# ----------start test bidirect lstm----------
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 30, 1)]      0
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 30, 100)      40800       input_4[0][0]
# __________________________________________________________________________________________________
# last_hidden_state (Lambda)      (None, 100)          0           lstm_4[0][0]
# __________________________________________________________________________________________________
# attention_score_vec (Dense)     (None, 30, 100)      10000       lstm_4[0][0]
# __________________________________________________________________________________________________
# attention_score (Dot)           (None, 30)           0           last_hidden_state[0][0]
#                                                                  attention_score_vec[0][0]
# __________________________________________________________________________________________________
# attention_weight (Activation)   (None, 30)           0           attention_score[0][0]
# __________________________________________________________________________________________________
# context_vector (Dot)            (None, 100)          0           lstm_4[0][0]
#                                                                  attention_weight[0][0]
# __________________________________________________________________________________________________
# attention_output (Concatenate)  (None, 200)          0           context_vector[0][0]
#                                                                  last_hidden_state[0][0]
# __________________________________________________________________________________________________
# attention_vector (Dense)        (None, 128)          25600       attention_output[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            129         attention_vector[0][0]
# ==================================================================================================
# Total params: 76,529
# Trainable params: 76,529
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ----------start train base lstm attention----------
# ----------start test base lstm attention----------
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 30, 1)]      0
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 30, 100)      40800       input_5[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   (None, 30, 50)       30200       lstm_5[0][0]
# __________________________________________________________________________________________________
# last_hidden_state (Lambda)      (None, 50)           0           lstm_6[0][0]
# __________________________________________________________________________________________________
# attention_score_vec (Dense)     (None, 30, 50)       2500        lstm_6[0][0]
# __________________________________________________________________________________________________
# attention_score (Dot)           (None, 30)           0           last_hidden_state[0][0]
#                                                                  attention_score_vec[0][0]
# __________________________________________________________________________________________________
# attention_weight (Activation)   (None, 30)           0           attention_score[0][0]
# __________________________________________________________________________________________________
# context_vector (Dot)            (None, 50)           0           lstm_6[0][0]
#                                                                  attention_weight[0][0]
# __________________________________________________________________________________________________
# attention_output (Concatenate)  (None, 100)          0           context_vector[0][0]
#                                                                  last_hidden_state[0][0]
# __________________________________________________________________________________________________
# attention_vector (Dense)        (None, 128)          12800       attention_output[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            129         attention_vector[0][0]
# ==================================================================================================
# Total params: 86,429
# Trainable params: 86,429
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ----------start train stack lstm attention----------
# ----------start test stack lstm attention----------
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 30, 1)]      0
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 30, 200)      81600       input_6[0][0]
# __________________________________________________________________________________________________
# lstm_8 (LSTM)                   (None, 30, 50)       50200       bidirectional_1[0][0]
# __________________________________________________________________________________________________
# last_hidden_state (Lambda)      (None, 50)           0           lstm_8[0][0]
# __________________________________________________________________________________________________
# attention_score_vec (Dense)     (None, 30, 50)       2500        lstm_8[0][0]
# __________________________________________________________________________________________________
# attention_score (Dot)           (None, 30)           0           last_hidden_state[0][0]
#                                                                  attention_score_vec[0][0]
# __________________________________________________________________________________________________
# attention_weight (Activation)   (None, 30)           0           attention_score[0][0]
# __________________________________________________________________________________________________
# context_vector (Dot)            (None, 50)           0           lstm_8[0][0]
#                                                                  attention_weight[0][0]
# __________________________________________________________________________________________________
# attention_output (Concatenate)  (None, 100)          0           context_vector[0][0]
#                                                                  last_hidden_state[0][0]
# __________________________________________________________________________________________________
# attention_vector (Dense)        (None, 128)          12800       attention_output[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            129         attention_vector[0][0]
# ==================================================================================================
# Total params: 147,229
# Trainable params: 147,229
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ----------start train bidirect lstm attention----------
# ----------start test bidirect lstm attention----------

# %%
import matplotlib.pyplot as plt
for j in range (len(histroy_list)):
    plt.figure(figsize=(15,5))
    plt.plot(histroy_list[j].history['loss'], label='train')
    plt.plot(histroy_list[j].history['val_loss'], label='test')
    plt.title(f'{model_list[j]}')
    plt.legend()
    now = datetime.now()
    current_time = now.strftime("%H:%M:%S")
    # plt.savefig(f'Results/ Results Plot test - {model_list[j]} {current_time}.jpg')
    # plt.show()
# Out:
# /home/john/anaconda3/envs/lstm_tf2/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime instead.

# %%
# invert predictions
def data_rescaler(input_data):
    output_data = scaler.inverse_transform(input_data)
    return output_data

# %%
import math
from keras import backend as K
from keras.metrics import mean_absolute_error, mean_absolute_percentage_error
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
# metric code
model_metric_stack = []
metric_list = ['Train RMSE', 'Test RMSE', 'Train MAPE', 'Test MAPE', 'Train MAE', 'Test MAE']
for i in range(len(model_list)):
    all_metric_stack = []
    trainY = data_rescaler(y_T)
    testY = data_rescaler(y_t)
    trainPredict = data_rescaler(train_pred_list[i])
    testPredict = data_rescaler(test_pred_list[i])
    # RMSE
    all_metric_stack.append((root_mean_squared_error(trainY[:,0], trainPredict[:,0])).numpy())
    all_metric_stack.append((root_mean_squared_error(testY[:,0], testPredict[:,0])).numpy())
    # MAPE
    all_metric_stack.append((mean_absolute_percentage_error(trainY[:,0], trainPredict[:,0])).numpy())
    all_metric_stack.append((mean_absolute_percentage_error(testY[:,0], testPredict[:,0])).numpy())
    # MAE
    all_metric_stack.append((mean_absolute_error(trainY[:,0], trainPredict[:,0])).numpy())
    all_metric_stack.append((mean_absolute_error(testY[:,0], testPredict[:,0])).numpy())
    model_metric_stack.append(all_metric_stack)

    # shift train predictions for plotting
    trainPredictPlot = np.empty_like(df_n)
    trainPredictPlot[:, :] = np.nan
    trainPredictPlot[30:len(trainPredict)+30, :] = trainPredict
    # shift test predictions for plotting
    testPredictPlot = np.empty_like(df_n)
    testPredictPlot[:, :] = np.nan
    testPredictPlot[len(trainPredict)+60:, :] = testPredict
    # plot baseline and predictions
    plt.figure(figsize=(20,5))
    plt.title(f'{model_list[i]}')
    plt.plot(scaler.inverse_transform(df_n), linewidth=1.5, label = 'Ground Turth')
    plt.plot(trainPredictPlot, linewidth=1, label='Train')
    plt.plot(testPredictPlot, linewidth=1, Label='Test')
    plt.legend(fontsize=8)
    if not os.path.exists('Results'):
        os.makedirs('Results')
    # plt.savefig(f'Results/{model_list[i]}plot baseline and predictions test - {current_time}.jpg')
    plt.show()





fig = plt.figure(figsize=(12, 4))
plt.axis('off')
plt.axis('tight')
plt.title('ALL LSTM Model Results')
tab1 = plt.table(cellText=model_metric_stack, rowLabels = model_list, colLabels=metric_list, cellLoc='center',loc='center')
tab1.scale(1.5,1.5)
tab1.set_fontsize(14)
# Out:
# /home/john/anaconda3/envs/lstm_tf2/lib/python3.6/site-packages/ipykernel_launcher.py:34: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# /home/john/anaconda3/envs/lstm_tf2/lib/python3.6/site-packages/ipykernel_launcher.py:34: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# /home/john/anaconda3/envs/lstm_tf2/lib/python3.6/site-packages/ipykernel_launcher.py:34: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# /home/john/anaconda3/envs/lstm_tf2/lib/python3.6/site-packages/ipykernel_launcher.py:34: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# /home/john/anaconda3/envs/lstm_tf2/lib/python3.6/site-packages/ipykernel_launcher.py:34: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# /home/john/anaconda3/envs/lstm_tf2/lib/python3.6/site-packages/ipykernel_launcher.py:34: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
