# %%
import torch, shap, glob, os
import numpy as np

# %%
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import train_test_split
# train val data path, checkpoint config
model_type = 'mlp'
version_type = 'ver4'
convet_index_dict = {'ver1': 'Integer', 'ver2': 'EIIP', 'ver3': 'Atomic', 'ver4': 'Voss'}
if model_type == 'cnn':
    npy_path = f'./np_image_totalunit/tsne-binary-perplexity=5-pixel=100[{convet_index_dict[version_type]}]/'
    save_weight_path = f'./model/weights_res18_tsne-binary-perplexity=50-pixel=100[{convet_index_dict[version_type]}]/'
    npy_data_list = [os.path.join(npy_path,'image_npy',i ) for i in sorted(os.listdir(os.path.join(npy_path,'image_npy')))]
else:
    npy_path = f'./np_image_totalunit/mlp_{convet_index_dict[version_type]}/'
    save_weight_path =f'./model/weights_mlp-binary-[{convet_index_dict[version_type]}]/'
    npy_data_list = np.load(f'./np_image_totalunit/mlp_{convet_index_dict[version_type]}/gene.npy')
if not os.path.exists(save_weight_path):
    os.mkdir(save_weight_path)

weights_name = f"weights_binaryclass_Covid19[-NACGT].final-{convet_index_dict[version_type]}.pt"
path2weights = os.path.join(save_weight_path,weights_name)
label_ = np.load(os.path.join(npy_path,'label.npy'))

# split train, val data
X_train, X_test, y_train, y_test = train_test_split(npy_data_list, label_,stratify = label_, test_size=0.25, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train,stratify = y_train, test_size=0.15, random_state=42)
print('train: ', len(X_train), '|| val: ', len(X_val), '|| test: ', len(X_test))
# Out:
# train:  723 || val:  128 || test:  284

# %%
from function import torch_dataset_func
train_ld = torch_dataset_func(model_type = model_type)
train_ds = train_ld.get_TransferDataset(data_list= X_train, labels= y_train, batch_size = 32, shuffle = True)
val_ld = torch_dataset_func(model_type = model_type)
val_ds = val_ld.get_TransferDataset(data_list= X_val, labels= y_val, batch_size = 32, shuffle = False)
print(len(train_ds), len(val_ds))
# Out:
# 23 4

# %%
from train_val import train_val_function
params_train={
    "num_epochs": 200,
    "optimizer": 'Adam',
    "loss_func": 'BCE',
    "train_dl": train_ds,
    "val_dl": val_ds,
    "sanity_check": False,
    "lr_scheduler":  'ReduceLROnPlateau',
    "path2weights": path2weights,
    }

start_train = train_val_function()
if model_type !='cnn':
    start_train.model_config(model_type = model_type, data_shape = X_train.shape, class_num = 1, use_cuda = True)
else:
    start_train.model_config(model_type = model_type, data_shape = None, class_num = 1, use_cuda = True)

# %%
# start_train.get_model()

# %%
loss_history, metric_history, auc_history = start_train.train_val_main(params_train)
# Out:
# Epoch 0/199, current lr=0.003
# Copied best model weights!
# train loss: 0.693213, dev loss: 0.692370,  train accuracy: 39.09,valid accuracy: 39.06
# train auc: 76.03,valid auc: 82.59
# ----------
# Epoch 1/199, current lr=0.003
# Copied best model weights!
# train loss: 0.651618, dev loss: 0.653872,  train accuracy: 39.75,valid accuracy: 39.06
# train auc: 86.38,valid auc: 85.69
# ----------
# Epoch 2/199, current lr=0.003
# train loss: 0.613341, dev loss: 0.668133,  train accuracy: 39.37,valid accuracy: 40.62
# train auc: 93.24,valid auc: 89.46
# ----------
# Epoch 3/199, current lr=0.003
# train loss: 0.596576, dev loss: 0.726322,  train accuracy: 39.05,valid accuracy: 39.06
# train auc: 94.80,valid auc: 93.57
# ----------
# Epoch 4/199, current lr=0.003
# train loss: 0.584798, dev loss: 0.711832,  train accuracy: 39.47,valid accuracy: 39.84
# train auc: 97.23,valid auc: 72.40
# ----------
# Epoch 5/199, current lr=0.003
# Copied best model weights!
# train loss: 0.583290, dev loss: 0.617653,  train accuracy: 39.73,valid accuracy: 39.84
# train auc: 96.95,valid auc: 92.03
# ----------
# Epoch 6/199, current lr=0.003
# train loss: 0.578412, dev loss: 0.803805,  train accuracy: 40.46,valid accuracy: 40.62
# train auc: 96.92,valid auc: 82.24
# ----------
# Epoch 7/199, current lr=0.003
# Copied best model weights!
# train loss: 0.576545, dev loss: 0.587183,  train accuracy: 40.96,valid accuracy: 40.62
# train auc: 96.73,valid auc: 95.49
# ----------
# Epoch 8/199, current lr=0.003
# train loss: 0.591283, dev loss: 0.596093,  train accuracy: 41.01,valid accuracy: 39.84
# train auc: 94.66,valid auc: 93.66
# ----------
# Epoch 9/199, current lr=0.003
# train loss: 0.575014, dev loss: 0.617417,  train accuracy: 41.41,valid accuracy: 54.69
# train auc: 96.97,valid auc: 95.07
# ----------
# Epoch 10/199, current lr=0.003
# train loss: 0.572344, dev loss: 0.612251,  train accuracy: 40.96,valid accuracy: 40.62
# train auc: 97.68,valid auc: 91.38
# ----------
# Epoch 11/199, current lr=0.003
# train loss: 0.570254, dev loss: 0.595178,  train accuracy: 42.63,valid accuracy: 42.19
# train auc: 96.44,valid auc: 92.13
# ----------
# Epoch 12/199, current lr=0.003
# train loss: 0.574003, dev loss: 0.598169,  train accuracy: 43.33,valid accuracy: 46.09
# train auc: 96.44,valid auc: 89.36
# ----------
# Epoch 13/199, current lr=0.003
# Epoch 00014: reducing learning rate of group 0 to 1.5000e-03.
# Loading best model weights!
# train loss: 0.569112, dev loss: 0.633671,  train accuracy: 43.09,valid accuracy: 41.41
# train auc: 97.04,valid auc: 83.64
# ----------
# Epoch 14/199, current lr=0.0015
# train loss: 0.568348, dev loss: 0.611840,  train accuracy: 40.60,valid accuracy: 39.06
# train auc: 98.32,valid auc: 94.13
# ----------
# Epoch 15/199, current lr=0.0015
# train loss: 0.575829, dev loss: 0.589620,  train accuracy: 41.77,valid accuracy: 39.84
# train auc: 97.94,valid auc: 92.71
# ----------
# Epoch 16/199, current lr=0.0015
# train loss: 0.566088, dev loss: 0.589978,  train accuracy: 41.28,valid accuracy: 39.84
# train auc: 97.76,valid auc: 92.12
# ----------
# Epoch 17/199, current lr=0.0015
# train loss: 0.569529, dev loss: 0.601047,  train accuracy: 42.10,valid accuracy: 41.41
# train auc: 96.83,valid auc: 89.81
# ----------
# Epoch 18/199, current lr=0.0015
# train loss: 0.565734, dev loss: 0.599788,  train accuracy: 42.13,valid accuracy: 39.84
# train auc: 98.35,valid auc: 91.35
# ----------
# Epoch 19/199, current lr=0.0015
# Copied best model weights!
# train loss: 0.568945, dev loss: 0.579975,  train accuracy: 44.41,valid accuracy: 41.41
# train auc: 98.56,valid auc: 95.46
# ----------
# Epoch 20/199, current lr=0.0015
# train loss: 0.571870, dev loss: 0.647652,  train accuracy: 44.67,valid accuracy: 78.12
# train auc: 98.05,valid auc: 91.99
# ----------
# Epoch 21/199, current lr=0.0015
# train loss: 0.568142, dev loss: 0.727412,  train accuracy: 43.50,valid accuracy: 39.06
# train auc: 97.87,valid auc: 85.74
# ----------
# Epoch 22/199, current lr=0.0015
# Copied best model weights!
# train loss: 0.571417, dev loss: 0.578709,  train accuracy: 43.36,valid accuracy: 39.84
# train auc: 97.32,valid auc: 93.61
# ----------
# Epoch 23/199, current lr=0.0015
# train loss: 0.568306, dev loss: 0.580239,  train accuracy: 45.39,valid accuracy: 43.75
# train auc: 96.90,valid auc: 94.99
# ----------
# Epoch 24/199, current lr=0.0015
# train loss: 0.579948, dev loss: 0.596772,  train accuracy: 44.31,valid accuracy: 40.62
# train auc: 95.72,valid auc: 92.24
# ----------
# Epoch 25/199, current lr=0.0015
# train loss: 0.569143, dev loss: 0.622450,  train accuracy: 45.50,valid accuracy: 46.09
# train auc: 97.90,valid auc: 82.83
# ----------
# Epoch 26/199, current lr=0.0015
# train loss: 0.562548, dev loss: 0.592916,  train accuracy: 47.08,valid accuracy: 42.97
# train auc: 97.93,valid auc: 91.03
# ----------
# Epoch 27/199, current lr=0.0015
# train loss: 0.563425, dev loss: 0.591967,  train accuracy: 48.30,valid accuracy: 63.28
# train auc: 97.22,valid auc: 95.23
# ----------
# Epoch 28/199, current lr=0.0015
# Epoch 00029: reducing learning rate of group 0 to 7.5000e-04.
# Loading best model weights!
# train loss: 0.564733, dev loss: 0.603501,  train accuracy: 45.58,valid accuracy: 43.75
# train auc: 96.95,valid auc: 90.12
# ----------
# Epoch 29/199, current lr=0.00075
# Copied best model weights!
# train loss: 0.564447, dev loss: 0.575573,  train accuracy: 45.77,valid accuracy: 42.19
# train auc: 97.80,valid auc: 93.77
# ----------
# Epoch 30/199, current lr=0.00075
# train loss: 0.562146, dev loss: 0.592230,  train accuracy: 44.85,valid accuracy: 42.19
# train auc: 98.15,valid auc: 94.06
# ----------
# Epoch 31/199, current lr=0.00075
# train loss: 0.559080, dev loss: 0.588291,  train accuracy: 45.77,valid accuracy: 42.19
# train auc: 98.21,valid auc: 95.47
# ----------
# Epoch 32/199, current lr=0.00075
# train loss: 0.563991, dev loss: 0.608058,  train accuracy: 45.72,valid accuracy: 41.41
# train auc: 97.94,valid auc: 91.79
# ----------
# Epoch 33/199, current lr=0.00075
# train loss: 0.563995, dev loss: 0.584719,  train accuracy: 46.76,valid accuracy: 47.66
# train auc: 98.40,valid auc: 93.99
# ----------
# Epoch 34/199, current lr=0.00075
# train loss: 0.559545, dev loss: 0.602623,  train accuracy: 44.85,valid accuracy: 42.19
# train auc: 98.33,valid auc: 91.73
# ----------
# Epoch 35/199, current lr=0.00075
# Epoch 00036: reducing learning rate of group 0 to 3.7500e-04.
# Loading best model weights!
# train loss: 0.558955, dev loss: 0.594379,  train accuracy: 46.89,valid accuracy: 42.97
# train auc: 98.62,valid auc: 92.89
# ----------
# Epoch 36/199, current lr=0.000375
# train loss: 0.560427, dev loss: 0.580816,  train accuracy: 45.17,valid accuracy: 42.97
# train auc: 98.44,valid auc: 94.13
# ----------
# Epoch 37/199, current lr=0.000375
# train loss: 0.561665, dev loss: 0.584387,  train accuracy: 46.27,valid accuracy: 41.41
# train auc: 98.58,valid auc: 93.95
# ----------
# Epoch 38/199, current lr=0.000375
# train loss: 0.560838, dev loss: 0.590622,  train accuracy: 44.31,valid accuracy: 41.41
# train auc: 98.75,valid auc: 94.48
# ----------
# Epoch 39/199, current lr=0.000375
# train loss: 0.558147, dev loss: 0.622092,  train accuracy: 46.35,valid accuracy: 42.97
# train auc: 98.03,valid auc: 90.12
# ----------
# Epoch 40/199, current lr=0.000375
# train loss: 0.557733, dev loss: 0.589954,  train accuracy: 48.08,valid accuracy: 45.31
# train auc: 98.24,valid auc: 93.92
# ----------
# Epoch 41/199, current lr=0.000375
# Epoch 00042: reducing learning rate of group 0 to 1.8750e-04.
# Loading best model weights!
# train loss: 0.556088, dev loss: 0.596132,  train accuracy: 47.76,valid accuracy: 41.41
# train auc: 97.86,valid auc: 93.69
# ----------
# Epoch 42/199, current lr=0.0001875
# train loss: 0.559276, dev loss: 0.582950,  train accuracy: 46.63,valid accuracy: 42.19
# train auc: 98.36,valid auc: 92.71
# ----------
# Epoch 43/199, current lr=0.0001875
# train loss: 0.562324, dev loss: 0.582235,  train accuracy: 45.98,valid accuracy: 43.75
# train auc: 98.57,valid auc: 93.50
# ----------
# Epoch 44/199, current lr=0.0001875
# train loss: 0.558822, dev loss: 0.587439,  train accuracy: 45.26,valid accuracy: 42.97
# train auc: 98.51,valid auc: 93.55
# ----------
# Epoch 45/199, current lr=0.0001875
# train loss: 0.559756, dev loss: 0.583987,  train accuracy: 46.27,valid accuracy: 44.53
# train auc: 98.46,valid auc: 93.99
# ----------
# Epoch 46/199, current lr=0.0001875
# train loss: 0.555830, dev loss: 0.583285,  train accuracy: 48.13,valid accuracy: 41.41
# train auc: 98.94,valid auc: 94.45
# ----------
# Epoch 47/199, current lr=0.0001875
# Epoch 00048: reducing learning rate of group 0 to 9.3750e-05.
# Loading best model weights!
# train loss: 0.557260, dev loss: 0.591010,  train accuracy: 46.99,valid accuracy: 41.41
# train auc: 98.54,valid auc: 94.45
# ----------
# Epoch 48/199, current lr=9.375e-05
# train loss: 0.560393, dev loss: 0.578235,  train accuracy: 44.86,valid accuracy: 42.97
# train auc: 98.47,valid auc: 93.43
# ----------
# Epoch 49/199, current lr=9.375e-05
# train loss: 0.559920, dev loss: 0.578813,  train accuracy: 46.80,valid accuracy: 42.19
# train auc: 98.12,valid auc: 93.53
# ----------
# Epoch 50/199, current lr=9.375e-05
# train loss: 0.561191, dev loss: 0.582721,  train accuracy: 46.27,valid accuracy: 42.97
# train auc: 97.73,valid auc: 92.90
# ----------
# Epoch 51/199, current lr=9.375e-05
# train loss: 0.560764, dev loss: 0.580971,  train accuracy: 46.90,valid accuracy: 43.75
# train auc: 98.20,valid auc: 93.30
# ----------
# Epoch 52/199, current lr=9.375e-05
# train loss: 0.560993, dev loss: 0.580842,  train accuracy: 45.90,valid accuracy: 42.19
# train auc: 98.06,valid auc: 93.93
# ----------
# Epoch 53/199, current lr=9.375e-05
# Epoch 00054: reducing learning rate of group 0 to 4.6875e-05.
# Loading best model weights!
# train loss: 0.559857, dev loss: 0.583895,  train accuracy: 46.95,valid accuracy: 40.62
# train auc: 98.69,valid auc: 93.69
# ----------
# Epoch 54/199, current lr=4.6875e-05
# train loss: 0.563717, dev loss: 0.580547,  train accuracy: 46.30,valid accuracy: 41.41
# train auc: 97.85,valid auc: 93.05
# ----------
# Epoch 55/199, current lr=4.6875e-05
# train loss: 0.561278, dev loss: 0.582743,  train accuracy: 45.57,valid accuracy: 41.41
# train auc: 98.58,valid auc: 92.86
# ----------
# Epoch 56/199, current lr=4.6875e-05
# train loss: 0.562418, dev loss: 0.581560,  train accuracy: 46.17,valid accuracy: 42.19
# train auc: 98.39,valid auc: 93.00
# ----------
# Epoch 57/199, current lr=4.6875e-05
# train loss: 0.560208, dev loss: 0.579910,  train accuracy: 45.30,valid accuracy: 42.19
# train auc: 98.54,valid auc: 93.53
# ----------
# Epoch 58/199, current lr=4.6875e-05
# train loss: 0.559618, dev loss: 0.583102,  train accuracy: 45.57,valid accuracy: 41.41
# train auc: 99.52,valid auc: 93.63
# ----------
# Epoch 59/199, current lr=4.6875e-05
# Epoch 00060: reducing learning rate of group 0 to 2.3438e-05.
# Loading best model weights!
# train loss: 0.558731, dev loss: 0.582469,  train accuracy: 46.36,valid accuracy: 42.19
# train auc: 98.89,valid auc: 93.00
# ----------
# Epoch 60/199, current lr=2.34375e-05
# train loss: 0.558395, dev loss: 0.578634,  train accuracy: 44.67,valid accuracy: 41.41
# train auc: 98.62,valid auc: 93.56
# ----------
# Epoch 61/199, current lr=2.34375e-05
# train loss: 0.561006, dev loss: 0.579008,  train accuracy: 45.59,valid accuracy: 41.41
# train auc: 98.63,valid auc: 93.43
# ----------
# Epoch 62/199, current lr=2.34375e-05
# train loss: 0.560184, dev loss: 0.580513,  train accuracy: 45.57,valid accuracy: 41.41
# train auc: 98.40,valid auc: 93.33
# ----------
# Epoch 63/199, current lr=2.34375e-05
# train loss: 0.558585, dev loss: 0.579825,  train accuracy: 46.54,valid accuracy: 42.97
# train auc: 98.33,valid auc: 93.50
# ----------
# Epoch 64/199, current lr=2.34375e-05
# train loss: 0.559625, dev loss: 0.580576,  train accuracy: 45.90,valid accuracy: 42.19
# train auc: 98.05,valid auc: 93.50
# ----------
# Epoch 65/199, current lr=2.34375e-05
# Epoch 00066: reducing learning rate of group 0 to 1.1719e-05.
# Loading best model weights!
# train loss: 0.560198, dev loss: 0.580576,  train accuracy: 46.94,valid accuracy: 42.19
# train auc: 98.58,valid auc: 93.63
# ----------
# Epoch 66/199, current lr=1.171875e-05
# train loss: 0.560484, dev loss: 0.579023,  train accuracy: 46.03,valid accuracy: 40.62
# train auc: 98.08,valid auc: 93.33
# ----------
# Epoch 67/199, current lr=1.171875e-05
# train loss: 0.559923, dev loss: 0.579524,  train accuracy: 45.72,valid accuracy: 40.62
# train auc: 98.26,valid auc: 93.38
# ----------
# Epoch 68/199, current lr=1.171875e-05
# train loss: 0.562492, dev loss: 0.579847,  train accuracy: 45.04,valid accuracy: 42.19
# train auc: 98.57,valid auc: 93.20
# ----------
# Epoch 69/199, current lr=1.171875e-05
# train loss: 0.560368, dev loss: 0.578669,  train accuracy: 46.22,valid accuracy: 42.97
# train auc: 98.37,valid auc: 93.63
# ----------
# Epoch 70/199, current lr=1.171875e-05
# train loss: 0.561182, dev loss: 0.581078,  train accuracy: 46.48,valid accuracy: 42.19
# train auc: 98.53,valid auc: 93.10
# ----------
# Epoch 71/199, current lr=1.171875e-05
# Epoch 00072: reducing learning rate of group 0 to 5.8594e-06.
# Loading best model weights!
# train loss: 0.562626, dev loss: 0.580534,  train accuracy: 45.44,valid accuracy: 42.19
# train auc: 97.51,valid auc: 93.50
# ----------
# Epoch 72/199, current lr=5.859375e-06
# train loss: 0.559059, dev loss: 0.580280,  train accuracy: 44.41,valid accuracy: 41.41
# train auc: 98.94,valid auc: 93.05
# ----------
# Epoch 73/199, current lr=5.859375e-06
# train loss: 0.562627, dev loss: 0.579338,  train accuracy: 45.99,valid accuracy: 42.19
# train auc: 98.40,valid auc: 93.35
# ----------
# Epoch 74/199, current lr=5.859375e-06
# train loss: 0.565265, dev loss: 0.579991,  train accuracy: 47.25,valid accuracy: 41.41
# train auc: 98.83,valid auc: 93.25
# ----------
# Epoch 75/199, current lr=5.859375e-06
# train loss: 0.558524, dev loss: 0.578602,  train accuracy: 46.14,valid accuracy: 41.41
# train auc: 98.46,valid auc: 93.43
# ----------
# Epoch 76/199, current lr=5.859375e-06
# train loss: 0.558465, dev loss: 0.579097,  train accuracy: 46.10,valid accuracy: 42.97
# train auc: 98.44,valid auc: 93.48
# ----------
# Epoch 77/199, current lr=5.859375e-06
# Epoch 00078: reducing learning rate of group 0 to 2.9297e-06.
# Loading best model weights!
# train loss: 0.558658, dev loss: 0.578476,  train accuracy: 45.40,valid accuracy: 42.97
# train auc: 98.72,valid auc: 93.81
# ----------
# Epoch 78/199, current lr=2.9296875e-06
# train loss: 0.559842, dev loss: 0.579488,  train accuracy: 46.09,valid accuracy: 42.19
# train auc: 98.78,valid auc: 93.25
# ----------
# Epoch 79/199, current lr=2.9296875e-06
# train loss: 0.559785, dev loss: 0.578513,  train accuracy: 47.09,valid accuracy: 41.41
# train auc: 98.32,valid auc: 93.38
# ----------
# Epoch 80/199, current lr=2.9296875e-06
# train loss: 0.561312, dev loss: 0.578391,  train accuracy: 45.95,valid accuracy: 41.41
# train auc: 98.37,valid auc: 93.33
# ----------
# Epoch 81/199, current lr=2.9296875e-06
# train loss: 0.563178, dev loss: 0.580403,  train accuracy: 47.66,valid accuracy: 40.62
# train auc: 98.43,valid auc: 93.11
# ----------
# Epoch 82/199, current lr=2.9296875e-06
# train loss: 0.562732, dev loss: 0.580012,  train accuracy: 46.89,valid accuracy: 41.41
# train auc: 98.57,valid auc: 93.33
# ----------
# Epoch 83/199, current lr=2.9296875e-06
# Epoch 00084: reducing learning rate of group 0 to 1.4648e-06.
# Loading best model weights!
# train loss: 0.561758, dev loss: 0.579687,  train accuracy: 46.39,valid accuracy: 41.41
# train auc: 98.21,valid auc: 93.48
# ----------
# Epoch 84/199, current lr=1.46484375e-06
# train loss: 0.558925, dev loss: 0.577986,  train accuracy: 45.77,valid accuracy: 41.41
# train auc: 98.17,valid auc: 93.66
# ----------
# Epoch 85/199, current lr=1.46484375e-06
# train loss: 0.565475, dev loss: 0.579511,  train accuracy: 46.03,valid accuracy: 41.41
# train auc: 98.35,valid auc: 93.71
# ----------
# Epoch 86/199, current lr=1.46484375e-06
# train loss: 0.562860, dev loss: 0.578963,  train accuracy: 45.80,valid accuracy: 41.41
# train auc: 98.57,valid auc: 93.71
# ----------
# Epoch 87/199, current lr=1.46484375e-06
# train loss: 0.561971, dev loss: 0.578614,  train accuracy: 45.80,valid accuracy: 41.41
# train auc: 98.15,valid auc: 93.66
# ----------
# Epoch 88/199, current lr=1.46484375e-06
# train loss: 0.560100, dev loss: 0.578577,  train accuracy: 47.20,valid accuracy: 42.19
# train auc: 98.60,valid auc: 93.48
# ----------
# Epoch 89/199, current lr=1.46484375e-06
# Epoch 00090: reducing learning rate of group 0 to 7.3242e-07.
# Loading best model weights!
# train loss: 0.560845, dev loss: 0.579521,  train accuracy: 45.40,valid accuracy: 42.19
# train auc: 98.78,valid auc: 93.48
# ----------
# Epoch 90/199, current lr=7.32421875e-07
# train loss: 0.560993, dev loss: 0.578037,  train accuracy: 47.00,valid accuracy: 42.97
# train auc: 97.64,valid auc: 93.66
# ----------
# Epoch 91/199, current lr=7.32421875e-07
# train loss: 0.562463, dev loss: 0.578675,  train accuracy: 45.80,valid accuracy: 41.41
# train auc: 98.58,valid auc: 93.71
# ----------
# Epoch 92/199, current lr=7.32421875e-07
# train loss: 0.559456, dev loss: 0.578347,  train accuracy: 45.77,valid accuracy: 41.41
# train auc: 98.38,valid auc: 93.56
# ----------
# Epoch 93/199, current lr=7.32421875e-07
# train loss: 0.561000, dev loss: 0.578311,  train accuracy: 45.14,valid accuracy: 41.41
# train auc: 98.41,valid auc: 93.51
# ----------
# Epoch 94/199, current lr=7.32421875e-07
# train loss: 0.561082, dev loss: 0.579940,  train accuracy: 46.90,valid accuracy: 41.41
# train auc: 98.46,valid auc: 93.33
# ----------
# Epoch 95/199, current lr=7.32421875e-07
# Epoch 00096: reducing learning rate of group 0 to 3.6621e-07.
# Loading best model weights!
# train loss: 0.563458, dev loss: 0.579657,  train accuracy: 44.85,valid accuracy: 41.41
# train auc: 97.93,valid auc: 93.48
# ----------
# Epoch 96/199, current lr=3.662109375e-07
# train loss: 0.566296, dev loss: 0.578257,  train accuracy: 44.99,valid accuracy: 41.41
# train auc: 97.89,valid auc: 93.51
# ----------
# Epoch 97/199, current lr=3.662109375e-07
# train loss: 0.562174, dev loss: 0.578666,  train accuracy: 47.03,valid accuracy: 41.41
# train auc: 98.71,valid auc: 93.56
# ----------
# Epoch 98/199, current lr=3.662109375e-07
# train loss: 0.560915, dev loss: 0.578977,  train accuracy: 46.54,valid accuracy: 41.41
# train auc: 98.35,valid auc: 93.33
# ----------
# Epoch 99/199, current lr=3.662109375e-07
# train loss: 0.561304, dev loss: 0.579091,  train accuracy: 46.04,valid accuracy: 42.19
# train auc: 98.20,valid auc: 93.48
# ----------
# Epoch 100/199, current lr=3.662109375e-07
# train loss: 0.560478, dev loss: 0.579611,  train accuracy: 46.26,valid accuracy: 41.41
# train auc: 98.48,valid auc: 93.56
# ----------
# Epoch 101/199, current lr=3.662109375e-07
# Epoch 00102: reducing learning rate of group 0 to 1.8311e-07.
# Loading best model weights!
# train loss: 0.563434, dev loss: 0.579254,  train accuracy: 45.90,valid accuracy: 41.41
# train auc: 98.12,valid auc: 93.48
# ----------
# Epoch 102/199, current lr=1.8310546875e-07
# train loss: 0.563909, dev loss: 0.577939,  train accuracy: 45.95,valid accuracy: 42.19
# train auc: 98.24,valid auc: 93.71
# ----------
# Epoch 103/199, current lr=1.8310546875e-07
# train loss: 0.559442, dev loss: 0.579149,  train accuracy: 44.67,valid accuracy: 42.19
# train auc: 98.47,valid auc: 93.48
# ----------
# Epoch 104/199, current lr=1.8310546875e-07
# train loss: 0.563227, dev loss: 0.578955,  train accuracy: 46.67,valid accuracy: 41.41
# train auc: 98.38,valid auc: 93.61
# ----------
# Epoch 105/199, current lr=1.8310546875e-07
# train loss: 0.562555, dev loss: 0.579559,  train accuracy: 46.76,valid accuracy: 42.19
# train auc: 98.08,valid auc: 93.20
# ----------
# Epoch 106/199, current lr=1.8310546875e-07
# train loss: 0.562537, dev loss: 0.578912,  train accuracy: 46.03,valid accuracy: 40.62
# train auc: 98.26,valid auc: 93.56
# ----------
# Epoch 107/199, current lr=1.8310546875e-07
# Epoch 00108: reducing learning rate of group 0 to 9.1553e-08.
# Loading best model weights!
# train loss: 0.561786, dev loss: 0.578220,  train accuracy: 45.81,valid accuracy: 42.19
# train auc: 98.47,valid auc: 93.71
# ----------
# Epoch 108/199, current lr=9.1552734375e-08
# train loss: 0.560470, dev loss: 0.578406,  train accuracy: 46.07,valid accuracy: 42.19
# train auc: 98.55,valid auc: 93.71
# ----------
# Epoch 109/199, current lr=9.1552734375e-08
# train loss: 0.564193, dev loss: 0.579246,  train accuracy: 45.86,valid accuracy: 42.19
# train auc: 97.77,valid auc: 93.48
# ----------
# Epoch 110/199, current lr=9.1552734375e-08
# train loss: 0.561775, dev loss: 0.578425,  train accuracy: 45.49,valid accuracy: 42.19
# train auc: 98.10,valid auc: 93.71
# ----------
# Epoch 111/199, current lr=9.1552734375e-08
# train loss: 0.563900, dev loss: 0.578630,  train accuracy: 45.57,valid accuracy: 42.19
# train auc: 98.43,valid auc: 93.71
# ----------
# Epoch 112/199, current lr=9.1552734375e-08
# train loss: 0.564217, dev loss: 0.580568,  train accuracy: 47.58,valid accuracy: 41.41
# train auc: 98.10,valid auc: 93.11
# ----------
# Epoch 113/199, current lr=9.1552734375e-08
# Epoch 00114: reducing learning rate of group 0 to 4.5776e-08.
# Loading best model weights!
# train loss: 0.561875, dev loss: 0.579021,  train accuracy: 44.63,valid accuracy: 40.62
# train auc: 97.80,valid auc: 93.61
# ----------
# Epoch 114/199, current lr=4.57763671875e-08
# train loss: 0.561868, dev loss: 0.577935,  train accuracy: 45.90,valid accuracy: 42.19
# train auc: 98.34,valid auc: 93.71
# ----------
# Epoch 115/199, current lr=4.57763671875e-08
# train loss: 0.562757, dev loss: 0.579972,  train accuracy: 45.72,valid accuracy: 42.19
# train auc: 98.10,valid auc: 93.30
# ----------
# Epoch 116/199, current lr=4.57763671875e-08
# train loss: 0.558116, dev loss: 0.579277,  train accuracy: 45.32,valid accuracy: 41.41
# train auc: 98.30,valid auc: 93.28
# ----------
# Epoch 117/199, current lr=4.57763671875e-08
# train loss: 0.560123, dev loss: 0.578678,  train accuracy: 45.95,valid accuracy: 41.41
# train auc: 98.25,valid auc: 93.33
# ----------
# Epoch 118/199, current lr=4.57763671875e-08
# train loss: 0.564199, dev loss: 0.579165,  train accuracy: 45.57,valid accuracy: 41.41
# train auc: 97.80,valid auc: 93.58
# ----------
# Epoch 119/199, current lr=4.57763671875e-08
# Epoch 00120: reducing learning rate of group 0 to 2.2888e-08.
# Loading best model weights!
# train loss: 0.561510, dev loss: 0.579526,  train accuracy: 45.27,valid accuracy: 41.41
# train auc: 97.73,valid auc: 93.33
# ----------
# Epoch 120/199, current lr=2.288818359375e-08
# train loss: 0.566774, dev loss: 0.578771,  train accuracy: 45.90,valid accuracy: 41.41
# train auc: 97.93,valid auc: 93.43
# ----------
# Epoch 121/199, current lr=2.288818359375e-08
# train loss: 0.563793, dev loss: 0.578716,  train accuracy: 44.82,valid accuracy: 42.19
# train auc: 98.49,valid auc: 93.43
# ----------
# Epoch 122/199, current lr=2.288818359375e-08
# train loss: 0.562187, dev loss: 0.578798,  train accuracy: 46.44,valid accuracy: 41.41
# train auc: 98.54,valid auc: 93.66
# ----------
# Epoch 123/199, current lr=2.288818359375e-08
# train loss: 0.561274, dev loss: 0.580246,  train accuracy: 45.39,valid accuracy: 40.62
# train auc: 98.33,valid auc: 93.61
# ----------
# Epoch 124/199, current lr=2.288818359375e-08
# train loss: 0.563829, dev loss: 0.578367,  train accuracy: 45.62,valid accuracy: 42.19
# train auc: 98.56,valid auc: 93.71
# ----------
# Epoch 125/199, current lr=2.288818359375e-08
# Epoch 00126: reducing learning rate of group 0 to 1.1444e-08.
# Loading best model weights!
# train loss: 0.564441, dev loss: 0.579212,  train accuracy: 46.48,valid accuracy: 42.19
# train auc: 98.02,valid auc: 93.48
# ----------
# Epoch 126/199, current lr=1.1444091796875e-08
# train loss: 0.561268, dev loss: 0.579166,  train accuracy: 45.94,valid accuracy: 41.41
# train auc: 97.97,valid auc: 93.43
# ----------
# Epoch 127/199, current lr=1.1444091796875e-08
# train loss: 0.560637, dev loss: 0.579615,  train accuracy: 45.22,valid accuracy: 41.41
# train auc: 98.67,valid auc: 93.10
# ----------
# Epoch 128/199, current lr=1.1444091796875e-08
# train loss: 0.564760, dev loss: 0.579053,  train accuracy: 44.84,valid accuracy: 42.19
# train auc: 97.85,valid auc: 93.61
# ----------
# Epoch 129/199, current lr=1.1444091796875e-08
# train loss: 0.560097, dev loss: 0.579215,  train accuracy: 46.71,valid accuracy: 42.19
# train auc: 98.48,valid auc: 93.48
# ----------
# Epoch 130/199, current lr=1.1444091796875e-08
# train loss: 0.561728, dev loss: 0.578025,  train accuracy: 45.04,valid accuracy: 41.41
# train auc: 98.44,valid auc: 93.38
# ----------
# Epoch 131/199, current lr=1.1444091796875e-08
# train loss: 0.560293, dev loss: 0.579349,  train accuracy: 45.62,valid accuracy: 42.19
# train auc: 98.45,valid auc: 93.56
# ----------
# Epoch 132/199, current lr=1.1444091796875e-08
# train loss: 0.564508, dev loss: 0.578911,  train accuracy: 44.35,valid accuracy: 41.41
# train auc: 98.63,valid auc: 93.71
# ----------
# Epoch 133/199, current lr=1.1444091796875e-08
# train loss: 0.558789, dev loss: 0.578703,  train accuracy: 46.10,valid accuracy: 42.19
# train auc: 98.89,valid auc: 93.28
# ----------
# Epoch 134/199, current lr=1.1444091796875e-08
# train loss: 0.560088, dev loss: 0.579335,  train accuracy: 46.44,valid accuracy: 41.41
# train auc: 98.12,valid auc: 93.43
# ----------
# Epoch 135/199, current lr=1.1444091796875e-08
# train loss: 0.559659, dev loss: 0.578168,  train accuracy: 45.18,valid accuracy: 42.19
# train auc: 98.72,valid auc: 93.71
# ----------
# Epoch 136/199, current lr=1.1444091796875e-08
# train loss: 0.562528, dev loss: 0.578115,  train accuracy: 46.50,valid accuracy: 42.19
# train auc: 98.20,valid auc: 93.38
# ----------
# Epoch 137/199, current lr=1.1444091796875e-08
# train loss: 0.563815, dev loss: 0.579525,  train accuracy: 45.08,valid accuracy: 42.19
# train auc: 98.64,valid auc: 93.56
# ----------
# Epoch 138/199, current lr=1.1444091796875e-08
# train loss: 0.563085, dev loss: 0.579535,  train accuracy: 46.26,valid accuracy: 41.41
# train auc: 98.12,valid auc: 93.33
# ----------
# Epoch 139/199, current lr=1.1444091796875e-08
# train loss: 0.561846, dev loss: 0.579280,  train accuracy: 47.26,valid accuracy: 41.41
# train auc: 98.50,valid auc: 93.71
# ----------
# Epoch 140/199, current lr=1.1444091796875e-08
# train loss: 0.563400, dev loss: 0.579134,  train accuracy: 45.94,valid accuracy: 42.19
# train auc: 97.52,valid auc: 93.56
# ----------
# Epoch 141/199, current lr=1.1444091796875e-08
# train loss: 0.563228, dev loss: 0.579926,  train accuracy: 46.17,valid accuracy: 40.62
# train auc: 98.38,valid auc: 93.38
# ----------
# Epoch 142/199, current lr=1.1444091796875e-08
# train loss: 0.566317, dev loss: 0.578935,  train accuracy: 46.12,valid accuracy: 41.41
# train auc: 98.25,valid auc: 93.46
# ----------
# Epoch 143/199, current lr=1.1444091796875e-08
# train loss: 0.560009, dev loss: 0.579438,  train accuracy: 46.77,valid accuracy: 41.41
# train auc: 98.18,valid auc: 93.33
# ----------
# Epoch 144/199, current lr=1.1444091796875e-08
# train loss: 0.562924, dev loss: 0.579607,  train accuracy: 46.85,valid accuracy: 40.62
# train auc: 98.01,valid auc: 93.38
# ----------
# Epoch 145/199, current lr=1.1444091796875e-08
# train loss: 0.562459, dev loss: 0.580020,  train accuracy: 46.40,valid accuracy: 42.19
# train auc: 98.43,valid auc: 93.35
# ----------
# Epoch 146/199, current lr=1.1444091796875e-08
# train loss: 0.565193, dev loss: 0.579072,  train accuracy: 44.35,valid accuracy: 42.19
# train auc: 98.35,valid auc: 93.66
# ----------
# Epoch 147/199, current lr=1.1444091796875e-08
# train loss: 0.564474, dev loss: 0.579617,  train accuracy: 46.67,valid accuracy: 42.19
# train auc: 97.70,valid auc: 93.48
# ----------
# Epoch 148/199, current lr=1.1444091796875e-08
# train loss: 0.559878, dev loss: 0.578540,  train accuracy: 46.00,valid accuracy: 42.19
# train auc: 97.86,valid auc: 93.43
# ----------
# Epoch 149/199, current lr=1.1444091796875e-08
# train loss: 0.566098, dev loss: 0.579725,  train accuracy: 46.44,valid accuracy: 41.41
# train auc: 97.73,valid auc: 93.66
# ----------
# Epoch 150/199, current lr=1.1444091796875e-08
# train loss: 0.560383, dev loss: 0.578414,  train accuracy: 46.67,valid accuracy: 42.19
# train auc: 98.58,valid auc: 93.71
# ----------
# Epoch 151/199, current lr=1.1444091796875e-08
# train loss: 0.565999, dev loss: 0.578287,  train accuracy: 46.45,valid accuracy: 42.19
# train auc: 98.67,valid auc: 93.58
# ----------
# Epoch 152/199, current lr=1.1444091796875e-08
# train loss: 0.561849, dev loss: 0.579408,  train accuracy: 46.45,valid accuracy: 42.19
# train auc: 98.61,valid auc: 93.43
# ----------
# Epoch 153/199, current lr=1.1444091796875e-08
# train loss: 0.563110, dev loss: 0.580286,  train accuracy: 46.54,valid accuracy: 40.62
# train auc: 98.32,valid auc: 93.30
# ----------
# Epoch 154/199, current lr=1.1444091796875e-08
# train loss: 0.563216, dev loss: 0.580442,  train accuracy: 45.53,valid accuracy: 40.62
# train auc: 97.93,valid auc: 93.28
# ----------
# Epoch 155/199, current lr=1.1444091796875e-08
# train loss: 0.562931, dev loss: 0.578773,  train accuracy: 48.13,valid accuracy: 41.41
# train auc: 98.47,valid auc: 93.33
# ----------
# Epoch 156/199, current lr=1.1444091796875e-08
# train loss: 0.564467, dev loss: 0.579289,  train accuracy: 45.62,valid accuracy: 42.19
# train auc: 98.04,valid auc: 93.48
# ----------
# Epoch 157/199, current lr=1.1444091796875e-08
# train loss: 0.562151, dev loss: 0.578802,  train accuracy: 46.23,valid accuracy: 42.19
# train auc: 98.10,valid auc: 93.58
# ----------
# Epoch 158/199, current lr=1.1444091796875e-08
# train loss: 0.563050, dev loss: 0.579153,  train accuracy: 46.80,valid accuracy: 41.41
# train auc: 97.80,valid auc: 93.71
# ----------
# Epoch 159/199, current lr=1.1444091796875e-08
# train loss: 0.563484, dev loss: 0.578212,  train accuracy: 46.82,valid accuracy: 42.19
# train auc: 98.03,valid auc: 93.71
# ----------
# Epoch 160/199, current lr=1.1444091796875e-08
# train loss: 0.564069, dev loss: 0.580394,  train accuracy: 45.27,valid accuracy: 41.41
# train auc: 98.13,valid auc: 93.53
# ----------
# Epoch 161/199, current lr=1.1444091796875e-08
# train loss: 0.563709, dev loss: 0.579491,  train accuracy: 45.62,valid accuracy: 42.19
# train auc: 98.09,valid auc: 93.48
# ----------
# Epoch 162/199, current lr=1.1444091796875e-08
# train loss: 0.562896, dev loss: 0.578716,  train accuracy: 45.72,valid accuracy: 40.62
# train auc: 98.02,valid auc: 93.33
# ----------
# Epoch 163/199, current lr=1.1444091796875e-08
# train loss: 0.559902, dev loss: 0.578314,  train accuracy: 47.53,valid accuracy: 42.19
# train auc: 98.63,valid auc: 93.58
# ----------
# Epoch 164/199, current lr=1.1444091796875e-08
# train loss: 0.563755, dev loss: 0.579491,  train accuracy: 46.57,valid accuracy: 42.19
# train auc: 98.16,valid auc: 93.48
# ----------
# Epoch 165/199, current lr=1.1444091796875e-08
# train loss: 0.561793, dev loss: 0.579250,  train accuracy: 46.85,valid accuracy: 41.41
# train auc: 98.13,valid auc: 93.33
# ----------
# Epoch 166/199, current lr=1.1444091796875e-08
# train loss: 0.566328, dev loss: 0.578321,  train accuracy: 45.18,valid accuracy: 41.41
# train auc: 98.45,valid auc: 93.56
# ----------
# Epoch 167/199, current lr=1.1444091796875e-08
# train loss: 0.563725, dev loss: 0.578635,  train accuracy: 45.48,valid accuracy: 41.41
# train auc: 98.11,valid auc: 93.43
# ----------
# Epoch 168/199, current lr=1.1444091796875e-08
# train loss: 0.561863, dev loss: 0.578532,  train accuracy: 45.35,valid accuracy: 41.41
# train auc: 98.47,valid auc: 93.56
# ----------
# Epoch 169/199, current lr=1.1444091796875e-08
# train loss: 0.560502, dev loss: 0.578720,  train accuracy: 46.13,valid accuracy: 42.19
# train auc: 98.07,valid auc: 93.33
# ----------
# Epoch 170/199, current lr=1.1444091796875e-08
# train loss: 0.558690, dev loss: 0.579510,  train accuracy: 45.35,valid accuracy: 40.62
# train auc: 98.37,valid auc: 93.51
# ----------
# Epoch 171/199, current lr=1.1444091796875e-08
# train loss: 0.561377, dev loss: 0.578826,  train accuracy: 46.80,valid accuracy: 42.19
# train auc: 98.21,valid auc: 93.48
# ----------
# Epoch 172/199, current lr=1.1444091796875e-08
# train loss: 0.561904, dev loss: 0.580239,  train accuracy: 46.72,valid accuracy: 41.41
# train auc: 98.43,valid auc: 93.20
# ----------
# Epoch 173/199, current lr=1.1444091796875e-08
# train loss: 0.560642, dev loss: 0.579516,  train accuracy: 45.86,valid accuracy: 40.62
# train auc: 98.45,valid auc: 93.33
# ----------
# Epoch 174/199, current lr=1.1444091796875e-08
# train loss: 0.565395, dev loss: 0.578701,  train accuracy: 45.34,valid accuracy: 41.41
# train auc: 98.08,valid auc: 93.71
# ----------
# Epoch 175/199, current lr=1.1444091796875e-08
# train loss: 0.558982, dev loss: 0.579949,  train accuracy: 46.17,valid accuracy: 41.41
# train auc: 98.20,valid auc: 93.61
# ----------
# Epoch 176/199, current lr=1.1444091796875e-08
# train loss: 0.561988, dev loss: 0.578585,  train accuracy: 45.72,valid accuracy: 41.41
# train auc: 98.83,valid auc: 93.33
# ----------
# Epoch 177/199, current lr=1.1444091796875e-08
# train loss: 0.562267, dev loss: 0.579019,  train accuracy: 45.34,valid accuracy: 41.41
# train auc: 98.65,valid auc: 93.33
# ----------
# Epoch 178/199, current lr=1.1444091796875e-08
# train loss: 0.561174, dev loss: 0.578677,  train accuracy: 47.63,valid accuracy: 42.19
# train auc: 97.96,valid auc: 93.53
# ----------
# Epoch 179/199, current lr=1.1444091796875e-08
# train loss: 0.562814, dev loss: 0.579809,  train accuracy: 46.39,valid accuracy: 42.19
# train auc: 98.20,valid auc: 93.61
# ----------
# Epoch 180/199, current lr=1.1444091796875e-08
# train loss: 0.561667, dev loss: 0.578811,  train accuracy: 46.18,valid accuracy: 41.41
# train auc: 98.32,valid auc: 93.46
# ----------
# Epoch 181/199, current lr=1.1444091796875e-08
# train loss: 0.560408, dev loss: 0.579150,  train accuracy: 44.86,valid accuracy: 41.41
# train auc: 98.46,valid auc: 93.56
# ----------
# Epoch 182/199, current lr=1.1444091796875e-08
# train loss: 0.559671, dev loss: 0.578711,  train accuracy: 46.00,valid accuracy: 41.41
# train auc: 98.32,valid auc: 93.56
# ----------
# Epoch 183/199, current lr=1.1444091796875e-08
# train loss: 0.560455, dev loss: 0.580114,  train accuracy: 46.03,valid accuracy: 41.41
# train auc: 98.28,valid auc: 93.38
# ----------
# Epoch 184/199, current lr=1.1444091796875e-08
# train loss: 0.560649, dev loss: 0.578745,  train accuracy: 46.90,valid accuracy: 41.41
# train auc: 97.67,valid auc: 93.41
# ----------
# Epoch 185/199, current lr=1.1444091796875e-08
# train loss: 0.563885, dev loss: 0.578079,  train accuracy: 48.28,valid accuracy: 41.41
# train auc: 97.92,valid auc: 93.56
# ----------
# Epoch 186/199, current lr=1.1444091796875e-08
# train loss: 0.562271, dev loss: 0.579302,  train accuracy: 46.04,valid accuracy: 42.19
# train auc: 98.45,valid auc: 93.61
# ----------
# Epoch 187/199, current lr=1.1444091796875e-08
# train loss: 0.563397, dev loss: 0.577758,  train accuracy: 46.31,valid accuracy: 41.41
# train auc: 98.20,valid auc: 93.51
# ----------
# Epoch 188/199, current lr=1.1444091796875e-08
# train loss: 0.564279, dev loss: 0.578620,  train accuracy: 45.76,valid accuracy: 42.19
# train auc: 98.05,valid auc: 93.71
# ----------
# Epoch 189/199, current lr=1.1444091796875e-08
# train loss: 0.559762, dev loss: 0.579526,  train accuracy: 45.81,valid accuracy: 40.62
# train auc: 97.75,valid auc: 93.38
# ----------
# Epoch 190/199, current lr=1.1444091796875e-08
# train loss: 0.562944, dev loss: 0.578013,  train accuracy: 46.55,valid accuracy: 41.41
# train auc: 98.67,valid auc: 93.58
# ----------
# Epoch 191/199, current lr=1.1444091796875e-08
# train loss: 0.563888, dev loss: 0.579620,  train accuracy: 44.62,valid accuracy: 40.62
# train auc: 97.48,valid auc: 93.28
# ----------
# Epoch 192/199, current lr=1.1444091796875e-08
# train loss: 0.563229, dev loss: 0.578562,  train accuracy: 46.62,valid accuracy: 42.19
# train auc: 98.60,valid auc: 93.58
# ----------
# Epoch 193/199, current lr=1.1444091796875e-08
# train loss: 0.563435, dev loss: 0.578704,  train accuracy: 45.17,valid accuracy: 42.19
# train auc: 98.52,valid auc: 93.48
# ----------
# Epoch 194/199, current lr=1.1444091796875e-08
# train loss: 0.565634, dev loss: 0.579541,  train accuracy: 47.30,valid accuracy: 41.41
# train auc: 98.54,valid auc: 93.20
# ----------
# Epoch 195/199, current lr=1.1444091796875e-08
# train loss: 0.563131, dev loss: 0.578420,  train accuracy: 45.17,valid accuracy: 41.41
# train auc: 98.47,valid auc: 93.46
# ----------
# Epoch 196/199, current lr=1.1444091796875e-08
# train loss: 0.565124, dev loss: 0.579459,  train accuracy: 45.85,valid accuracy: 42.19
# train auc: 97.41,valid auc: 93.48
# ----------
# Epoch 197/199, current lr=1.1444091796875e-08
# train loss: 0.559110, dev loss: 0.578696,  train accuracy: 45.82,valid accuracy: 42.19
# train auc: 98.72,valid auc: 93.43
# ----------
# Epoch 198/199, current lr=1.1444091796875e-08
# train loss: 0.562157, dev loss: 0.580717,  train accuracy: 45.40,valid accuracy: 41.41
# train auc: 98.86,valid auc: 93.16
# ----------
# Epoch 199/199, current lr=1.1444091796875e-08
# train loss: 0.561979, dev loss: 0.579854,  train accuracy: 45.30,valid accuracy: 41.41
# train auc: 98.70,valid auc: 93.53
# ----------

# %%
import matplotlib.pyplot as plt
plt.plot(loss_history['train'])
plt.plot(loss_history['val'])
plt.legend(['train','val'])
plt.title(f'[{model_type} {convet_index_dict[version_type]}] loss history')
plt.savefig(os.path.join(save_weight_path, f'{model_type }_{weights_name[0:-3]} - loss_history.jpg'))

# %%
plt.plot(metric_history['train'])
plt.plot(metric_history['val'])
plt.legend(['train','val'])
plt.title(f'[{model_type} {convet_index_dict[version_type]}] accuracy history')
plt.savefig(os.path.join(save_weight_path, f'{model_type }_{weights_name[0:-3]} - accuracy_history.jpg'))

# %%
plt.plot(auc_history['train'])
plt.plot(auc_history['val'])
plt.legend(['train','val'])
plt.title(f'[{model_type} {convet_index_dict[version_type]}] auc history')
plt.savefig(os.path.join(save_weight_path, f'{model_type }_{weights_name[0:-3]} - auc_history.jpg'))
