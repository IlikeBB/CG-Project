# %%
import pandas as pd, os, random, math
import torch, numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
from torch.utils.data import TensorDataset, DataLoader
from torch.utils.tensorboard import SummaryWriter
from sklearn.model_selection import train_test_split
from sklearn import metrics
from torch.optim import Adam
from tqdm import tqdm
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
cudnn.benchmark = True
random.seed(1234)
torch.manual_seed(1234)

# %%
class logs_realtime_reply:
    def __init__(self):
        self.avg_dice = 0.0
        self.avg_loss=np.inf
        self.avg_tn = 0
        self.avg_fp = 0
        self.avg_fn = 0
        self.running_metic = {"Loss":0,"Accuracy":0, "AUC": 0}
        self.end_epoch_metric = None
    def metric_stack(self, inputs, targets, loss):
        with torch.no_grad():
            self.running_metic['Loss'] +=loss
            # metric setting
            SR = inputs.cpu().data.numpy()
            GT = targets.cpu().data.numpy()
            acc = metrics.accuracy_score(SR>0.5, GT)
            fpr, tpr, thresholds = metrics.roc_curve(GT, SR, pos_label=1)
            auc = metrics.auc(fpr, tpr)
            self.running_metic['Accuracy'] += round((acc), 5)
            self.running_metic['AUC'] += round((auc), 5)
    def mini_batch_reply(self, current_step, epoch, iter_len):
        avg_reply_metric = {"Loss":None, "Accuracy": None, "AUC": None}
        for j in avg_reply_metric:
            avg_reply_metric[j] = round(self.running_metic[j]/int(current_step),5)
        
        if current_step ==iter_len:
            self.end_epoch_metric = avg_reply_metric
        return avg_reply_metric

    def epoch_reply(self):
        return self.end_epoch_metric

# %%
class MLP(nn.Module):
    def __init__(self, num_classes, input_size):
        super(MLP,self).__init__()
        self.linear1 = nn.Linear(in_features=input_size, out_features=10)
        self.bn1 = nn.BatchNorm1d(10)
        self.dt1 = nn.Dropout(0.25)
        self.linear2 = nn.Linear(in_features=10, out_features=5)
        self.bn2 = nn.BatchNorm1d(5)
        self.dt2 = nn.Dropout(0.25)
        self.linear3 = nn.Linear(in_features=5, out_features=num_classes)
        
    def forward(self, x):
        x = self.bn1(self.linear1(x))
        x = F.relu(x)
        x = self.bn2(self.linear2(x))
        x = F.relu(x)
        x = self.linear3(x)
        x = torch.sigmoid(x)
        return x
        
    def initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.BatchNorm1d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                torch.nn.init.normal_(m.weight.data, 0, 0.01)
                m.bias.data.zero_()

# %%
def model_create():
    model = MLP(num_classes=1, input_size=25)
    model.initialize_weights()
    model.to(device)
    return model

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    global best_tacc, best_tauc
    get_logs_reply = logs_realtime_reply()
    model.train()
    # stream = tqdm(train_loader)
   
    for i, (text, label) in enumerate(train_loader, start=1):
        text = text.to(device)
        target = label.to(device)
        # print(text)
        output = model(text).squeeze(1)

        # print(output)
        # print(target)
        loss = criterion(output, target)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        get_logs_reply.metric_stack(output, target, loss = round(loss.item(), 5))
        avg_reply_metric = get_logs_reply.mini_batch_reply(i, epoch, len(train_loader))
        avg_reply_metric['lr'] = optimizer.param_groups[0]['lr']
        # stream.set_description(f"Epoch: {epoch}. Train. {str(avg_reply_metric)}")
    avg_reply_metric = get_logs_reply.epoch_reply()
    
    for x in avg_reply_metric:
        if x =='Accuracy' and avg_reply_metric[x] > best_tacc:
            best_tacc = avg_reply_metric[x]
            current_loss = avg_reply_metric['Loss']
            save_ck_name = f'{ck_pth}/best - tacc - {project_name}.pt'
            torch.save({
                    'epoch': epoch, 'model_state_dict': model.state_dict(), 'optimizer_state_dict': optimizer.state_dict(), 
                    'loss':  current_loss,}, save_ck_name)
            # print('save...', save_ck_name)
        if x=='AUC' and avg_reply_metric[x]>best_tauc:
            best_tauc = avg_reply_metric[x]
            current_loss = avg_reply_metric['Loss']
            best_ck_name = f'{ck_pth}/best - tauc - {project_name}.pt'
            torch.save({
                    'epoch': epoch, 'model_state_dict': model.state_dict(), 'optimizer_state_dict': optimizer.state_dict(), 
                    'loss':  current_loss,}, best_ck_name)
            # print('save...', best_ck_name)
        # print(avg_reply_metric)
        writer.add_scalar(f'{x}/Train {x}', avg_reply_metric[x], epoch)

# %%
def  train_valid_process_main(model, training_set, batch_size):
    global best_tacc, best_tauc
    # best_tloss = np.inf
    best_tauc = 0.00
    best_tacc = 0.00
    # Subject Dataloader Building
    train_loader = DataLoader(training_set, batch_size=batch_size, shuffle=True, num_workers=10)
    for epoch in tqdm(range(1, params["epochs"] + 1)):
        train(train_loader, model, loss, optimizer, epoch)
    print("Train","Best accuracy:", best_tacc, ' Best auc:', best_tauc)
    return model

# %%
data_df = pd.read_csv('./xlsx/12-17-rhees death_within28days+feature.csv')
# data_df = pd.read_csv('./xlsx/local_sepsis.csv')
# data_df = pd.read_csv('./xlsx/original_555 sepsis dataset.csv')
def dataloader(table):
    for i in table:
        if (i in ['ID','LOC','outcome'])==False:
            # print(i)
            cols_filter = [x for x in table[i] if math.isnan(float(x))==False ]
            med = np.median(cols_filter)
            table[i] = [med if math.isnan(float(x))==True else x for x in table[i]]
            min_cols, max_cols =np.min(cols_filter), np.max(cols_filter)

            normal = lambda x: (x - min_cols)/(max_cols - min_cols)
            table[i] = [normal(x) for x in table[i]]
            table[i] = [0 if math.isnan(float(x))==True else x for x in table[i]]
    return table
data_df = dataloader(data_df)
data_df
# Out:
#            ID  LOC  SOFA total  Albumin   D-dimer  Cortisol   Lactate  \
# 0          B1    1        0.00     0.50  0.023844  0.091176  0.058333
# 1          B2    1        0.04     0.50  0.023844  0.091176  0.058333
# 2          B3    1        0.04     0.50  0.023844  0.091176  0.058333
# 3          B4    1        0.00     0.50  0.023844  0.091176  0.058333
# 4          B5    1        0.00     0.50  0.023844  0.091176  0.058333
# ...       ...  ...         ...      ...       ...       ...       ...
# 16303  B16304    3        0.20     0.50  0.023844  0.091176  0.105556
# 16304  B16305    3        0.44     0.25  0.023844  0.082353  0.150000
# 16305  B16306    3        0.00     0.50  0.023844  0.091176  0.058333
# 16306  B16307    3        0.16     0.50  0.023844  0.091176  0.055556
# 16307  B16308    3        0.20     0.50  0.023844  0.091176  0.058333
#
#        SOFA score-Respiratory  Red Blood Cell       FDP  ...   pH  Pulse rate  \
# 0                        0.00             0.3  0.210526  ...  0.0    0.384615
# 1                        0.00             0.3  0.210526  ...  0.0    0.183761
# 2                        0.00             0.3  0.210526  ...  0.0    0.324786
# 3                        0.00             0.3  0.210526  ...  0.0    0.457265
# 4                        0.00             0.3  0.210526  ...  0.0    0.380342
# ...                       ...             ...       ...  ...  ...         ...
# 16303                    0.00             0.3  0.210526  ...  0.0    0.401709
# 16304                    0.75             0.2  0.210526  ...  0.0    0.474359
# 16305                    0.00             0.2  0.210526  ...  0.0    0.329060
# 16306                    0.00             0.4  0.210526  ...  0.0    0.341880
# 16307                    0.00             0.2  0.210526  ...  0.0    0.367521
#
#        Highest SOFA score-cardiov     AaDO2      pCO2       SBE      ABE  \
# 0                             0.0  0.887273  0.153005  0.439394  0.45614
# 1                             0.0  0.887273  0.153005  0.439394  0.45614
# 2                             0.0  0.887273  0.153005  0.439394  0.45614
# 3                             0.0  0.887273  0.153005  0.439394  0.45614
# 4                             0.0  0.887273  0.153005  0.439394  0.45614
# ...                           ...       ...       ...       ...      ...
# 16303                         0.0  0.887273  0.153005  0.439394  0.45614
# 16304                         0.0  0.887273  0.153005  0.439394  0.45614
# 16305                         0.0  0.887273  0.153005  0.439394  0.45614
# 16306                         0.0  0.887273  0.153005  0.439394  0.45614
# 16307                         0.0  0.887273  0.153005  0.439394  0.45614
#
#            FiO2  Total CO2  outcome
# 0      0.193878   0.529412        0
# 1      0.193878   0.529412        0
# 2      0.193878   0.529412        0
# 3      0.193878   0.529412        0
# 4      0.193878   0.529412        0
# ...         ...        ...      ...
# 16303  0.193878   0.529412        0
# 16304  0.795918   0.529412        0
# 16305  0.193878   0.529412        0
# 16306  0.193878   0.529412        0
# 16307  0.193878   0.529412        0
#
# [16308 rows x 28 columns]

# %%
import random 
# for i in range(50):
    # seed = random.randint(10,100)
for i in [1,2,3]:
    data_df_LOC = data_df[data_df["LOC"]==i]
    X_train, X_test, y_train, y_test = train_test_split(data_df_LOC.drop(['outcome'],axis=1), data_df_LOC['outcome'], 
                                                                                                        test_size=0.25, stratify=list(data_df_LOC['outcome']), random_state=123) #seed = 42, 123
    print("LOC:", i)
    print('train', ' 0: ', len(y_train)-sum(y_train),'1:',sum(y_train))
    print('valid', '0: ', len(y_test)-sum(y_test), '1:',sum(y_test))

    try:
        X_train_ = np.array(X_train.drop(['ID','LOC'],axis=1))
        X_test_ = np.array(X_test.drop(['ID','LOC'],axis=1))
        y_train_ = np.array(y_train)
        y_test_ = np.array(y_test)
    except:
        X_train_ = np.array(X_train.drop(['ID'],axis=1))
        X_test_ = np.array(X_test.drop(['ID'],axis=1))
        y_train_ = np.array(y_train)
        y_test_ = np.array(y_test)
    print(X_train_.shape, X_test_.shape, y_train_.shape, y_test_.shape)
    if True: #model record
        params = {
            "type": "Sepsis-Transfer",
            "model": 'MLP', #baseline = 'resnet18'
            "model_depth": 3,
            "device": "cuda",
            "opt": "Adam",
            "lr": 0.003, #baseline = 0.003
            "batch_size": 64, #baseline resnet18 : 8
            "epochs": 150,
            "fixing": "None"
            }
    training_set = TensorDataset(torch.FloatTensor(X_train_), torch.FloatTensor(y_train_))

    # checkpoint setting
    project_name = f"{params['type']} - {params['model']} - lr_{params['lr']} - CEL"
    project_folder = f"2021.12.17.t1 - Sepsis - MLP - {params['type']} - Local{i}-Transfer Pretrain Model"
    ck_pth = f'./checkpoint/{project_folder}'
    if os.path.exists(ck_pth)==False:
        os.mkdir(ck_pth)
    ck_name = project_name
    path = f'./checkpoint/{project_folder}/{project_name}.txt'
    f = open(path, 'w')
    lines = params
    f.writelines([f'{i} : {params[i]} \n' for i in params])
    f.close()
    tensorboard_logdir = f'./logsdir/S2/ {project_folder} - {project_name}'
    writer=SummaryWriter(tensorboard_logdir)
    # checkpoint = torch.load('./checkpoint/2021.12.10.t1 - Sepsis - MLP - Sepsis-original/best - tauc - Sepsis-original - MLP3 - lr_0.003 - CEL.pt', map_location=torch.device(device))
    model = model_create()
    # model.load_state_dict(checkpoint['model_state_dict'])
    loss = torch.nn.BCELoss()
    if params['opt']=='Adam':
        optimizer = Adam(model.parameters(), lr=params['lr'], betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)
    else:
        optimizer = torch.optim.SGD(model.parameters(), lr=params['lr'], weight_decay = 1e-4, momentum=0.9)
    logs  = train_valid_process_main(model, training_set, params['batch_size'])
    writer.close()
    validation_set = TensorDataset(torch.FloatTensor(X_test_), torch.FloatTensor(y_test_))
# Test
    test_loader = DataLoader(validation_set, batch_size=len(validation_set), drop_last=False, shuffle=False)
    checkpoint_path = f"./checkpoint/{project_folder}/best - tauc - {params['type']} - MLP - lr_0.003 - CEL.pt"
    checkpoint = torch.load(checkpoint_path, map_location=torch.device(device))
    model = model_create()
    model.load_state_dict(checkpoint['model_state_dict'])
    model.to('cpu')
    with torch.no_grad():
        for i, (text, label) in enumerate(test_loader, start=1):
            output = model(text.to('cpu'))
            label = label
        acc = metrics.accuracy_score(output>0.5, label)
        fpr, tpr, thresholds = metrics.roc_curve(label, output, pos_label=1)
        auc = metrics.auc(fpr, tpr)
        print("///-------Transfer Pretrain model-------///")
        print("Accuracy:", round(acc,5), "\nAUC:", round(auc,5))
        print("///-----------------Train &Test End-----------------///")
# Out:
# LOC: 1
# train  0:  908 1: 34
# valid 0:  303 1: 11
# (942, 25) (314, 25) (942,) (314,)
#   0%|          | 0/150 [00:00<?, ?it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#   1%|          | 1/150 [00:00<01:18,  1.90it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#   1%|▏         | 2/150 [00:01<01:18,  1.88it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#   2%|▏         | 3/150 [00:01<01:17,  1.91it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#   3%|▎         | 4/150 [00:02<01:16,  1.91it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#   3%|▎         | 5/150 [00:02<01:17,  1.88it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#   4%|▍         | 6/150 [00:03<01:14,  1.92it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#   5%|▍         | 7/150 [00:03<01:13,  1.95it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#   5%|▌         | 8/150 [00:04<01:11,  1.98it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#   6%|▌         | 9/150 [00:04<01:09,  2.02it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#   7%|▋         | 10/150 [00:05<01:08,  2.04it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#   7%|▋         | 11/150 [00:05<01:08,  2.04it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#   8%|▊         | 12/150 [00:06<01:06,  2.08it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#   9%|▊         | 13/150 [00:06<01:06,  2.06it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#   9%|▉         | 14/150 [00:07<01:05,  2.07it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  10%|█         | 15/150 [00:07<01:06,  2.04it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  12%|█▏        | 18/150 [00:09<01:06,  1.98it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  13%|█▎        | 19/150 [00:09<01:06,  1.98it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  14%|█▍        | 21/150 [00:10<01:04,  1.99it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  15%|█▍        | 22/150 [00:11<01:04,  1.97it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  15%|█▌        | 23/150 [00:11<01:04,  1.98it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  16%|█▌        | 24/150 [00:12<01:02,  2.02it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  17%|█▋        | 25/150 [00:12<01:01,  2.02it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  17%|█▋        | 26/150 [00:13<01:00,  2.04it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  18%|█▊        | 27/150 [00:13<01:00,  2.03it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  19%|█▊        | 28/150 [00:14<01:00,  2.02it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  20%|██        | 30/150 [00:15<00:59,  2.03it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  21%|██        | 31/150 [00:15<00:58,  2.04it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  23%|██▎       | 34/150 [00:16<00:56,  2.04it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  23%|██▎       | 35/150 [00:17<00:56,  2.04it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  24%|██▍       | 36/150 [00:17<00:55,  2.04it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  25%|██▍       | 37/150 [00:18<00:55,  2.03it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  25%|██▌       | 38/150 [00:19<00:56,  1.97it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  27%|██▋       | 40/150 [00:19<00:54,  2.01it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  27%|██▋       | 41/150 [00:20<00:53,  2.02it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  28%|██▊       | 42/150 [00:20<00:54,  1.99it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  29%|██▉       | 44/150 [00:21<00:52,  2.02it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  30%|███       | 45/150 [00:22<00:51,  2.02it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  31%|███       | 46/150 [00:22<00:51,  2.02it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  32%|███▏      | 48/150 [00:23<00:50,  2.02it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  33%|███▎      | 49/150 [00:24<00:49,  2.04it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  33%|███▎      | 50/150 [00:24<00:48,  2.05it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  35%|███▍      | 52/150 [00:25<00:48,  2.04it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  35%|███▌      | 53/150 [00:26<00:47,  2.05it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  36%|███▌      | 54/150 [00:26<00:46,  2.05it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  37%|███▋      | 55/150 [00:27<00:47,  1.99it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  38%|███▊      | 57/150 [00:28<00:45,  2.03it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  39%|███▊      | 58/150 [00:28<00:45,  2.02it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  40%|████      | 60/150 [00:29<00:45,  2.00it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  41%|████      | 61/150 [00:30<00:44,  2.00it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  41%|████▏     | 62/150 [00:30<00:45,  1.92it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  43%|████▎     | 65/150 [00:32<00:45,  1.87it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  44%|████▍     | 66/150 [00:33<00:45,  1.83it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  45%|████▍     | 67/150 [00:33<00:46,  1.80it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  45%|████▌     | 68/150 [00:34<00:45,  1.80it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  46%|████▌     | 69/150 [00:34<00:45,  1.80it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  47%|████▋     | 70/150 [00:35<00:43,  1.83it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  47%|████▋     | 71/150 [00:35<00:42,  1.88it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  48%|████▊     | 72/150 [00:36<00:41,  1.90it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  49%|████▊     | 73/150 [00:36<00:39,  1.94it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  49%|████▉     | 74/150 [00:37<00:38,  1.97it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  50%|█████     | 75/150 [00:37<00:38,  1.97it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  51%|█████     | 76/150 [00:38<00:37,  1.98it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  51%|█████▏    | 77/150 [00:38<00:36,  2.00it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  52%|█████▏    | 78/150 [00:39<00:35,  2.02it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  53%|█████▎    | 79/150 [00:39<00:35,  2.02it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  53%|█████▎    | 80/150 [00:40<00:34,  2.01it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  54%|█████▍    | 81/150 [00:40<00:34,  2.01it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  55%|█████▌    | 83/150 [00:41<00:33,  2.02it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  56%|█████▌    | 84/150 [00:42<00:34,  1.94it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  57%|█████▋    | 85/150 [00:42<00:33,  1.92it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  58%|█████▊    | 87/150 [00:43<00:32,  1.96it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  59%|█████▊    | 88/150 [00:44<00:31,  1.98it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  59%|█████▉    | 89/150 [00:44<00:30,  1.99it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  60%|██████    | 90/150 [00:45<00:29,  2.00it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  61%|██████    | 91/150 [00:45<00:29,  2.03it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  63%|██████▎   | 94/150 [00:47<00:27,  2.04it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  63%|██████▎   | 95/150 [00:47<00:27,  2.03it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  64%|██████▍   | 96/150 [00:48<00:26,  2.04it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  65%|██████▍   | 97/150 [00:48<00:25,  2.07it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  65%|██████▌   | 98/150 [00:49<00:25,  2.06it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  67%|██████▋   | 100/150 [00:50<00:24,  2.08it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  68%|██████▊   | 102/150 [00:51<00:23,  2.04it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  69%|██████▊   | 103/150 [00:51<00:23,  2.00it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  69%|██████▉   | 104/150 [00:52<00:22,  2.00it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  70%|███████   | 105/150 [00:52<00:22,  2.02it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  71%|███████   | 106/150 [00:53<00:21,  2.03it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  71%|███████▏  | 107/150 [00:53<00:20,  2.05it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  72%|███████▏  | 108/150 [00:54<00:20,  2.06it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  73%|███████▎  | 109/150 [00:54<00:19,  2.08it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  74%|███████▍  | 111/150 [00:55<00:18,  2.07it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  75%|███████▍  | 112/150 [00:56<00:18,  2.05it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  75%|███████▌  | 113/150 [00:56<00:18,  2.05it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  76%|███████▌  | 114/150 [00:57<00:17,  2.03it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  77%|███████▋  | 116/150 [00:58<00:16,  2.05it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  78%|███████▊  | 117/150 [00:58<00:16,  2.06it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  79%|███████▊  | 118/150 [00:59<00:15,  2.02it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  79%|███████▉  | 119/150 [00:59<00:15,  1.98it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  80%|████████  | 120/150 [01:00<00:15,  1.99it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  81%|████████  | 121/150 [01:00<00:14,  2.00it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  81%|████████▏ | 122/150 [01:01<00:13,  2.02it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  82%|████████▏ | 123/150 [01:01<00:13,  2.02it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  83%|████████▎ | 124/150 [01:02<00:12,  2.03it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  83%|████████▎ | 125/150 [01:02<00:12,  2.01it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  84%|████████▍ | 126/150 [01:03<00:11,  2.04it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  87%|████████▋ | 130/150 [01:04<00:09,  2.06it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  87%|████████▋ | 131/150 [01:05<00:09,  2.08it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  88%|████████▊ | 132/150 [01:05<00:08,  2.06it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  89%|████████▉ | 134/150 [01:06<00:07,  2.03it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  90%|█████████ | 135/150 [01:07<00:07,  2.02it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  91%|█████████ | 136/150 [01:07<00:07,  1.97it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  91%|█████████▏| 137/150 [01:08<00:06,  1.99it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  92%|█████████▏| 138/150 [01:08<00:05,  2.01it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  93%|█████████▎| 139/150 [01:09<00:05,  2.02it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  93%|█████████▎| 140/150 [01:09<00:04,  2.03it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  95%|█████████▍| 142/150 [01:10<00:03,  2.02it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  95%|█████████▌| 143/150 [01:11<00:03,  2.05it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  97%|█████████▋| 146/150 [01:12<00:01,  2.06it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  98%|█████████▊| 147/150 [01:13<00:01,  2.07it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
#  99%|█████████▊| 148/150 [01:13<00:00,  2.11it/s]/home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home/john/anaconda3/envs/lstm_pyt/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# 100%|██████████| 150/150 [01:14<00:00,  2.01it/s]
# Train Best accuracy: 0.96458  Best auc: 0.86401
# ///-------Transfer Pretrain model-------///
# Accuracy: 0.96497
# AUC: 0.75443
# ///-----------------Train &Test End-----------------///
# LOC: 2
# train  0:  1390 1: 303
# valid 0:  464 1: 101
# (1693, 25) (565, 25) (1693,) (565,)
# 100%|██████████| 150/150 [01:28<00:00,  1.70it/s]
# Train Best accuracy: 0.88633  Best auc: 0.88872
# ///-------Transfer Pretrain model-------///
# Accuracy: 0.82124
# AUC: 0.71084
# ///-----------------Train &Test End-----------------///
# LOC: 3
# train  0:  7727 1: 1868
# valid 0:  2576 1: 623
# (9595, 25) (3199, 25) (9595,) (3199,)
# 100%|██████████| 150/150 [03:40<00:00,  1.47s/it]
# Train Best accuracy: 0.83984  Best auc: 0.8316
# ///-------Transfer Pretrain model-------///
# Accuracy: 0.83088
# AUC: 0.81118
# ///-----------------Train &Test End-----------------///

# %%
'./checkpoint/2021.12.10.t1 - Sepsis - MLP - Sepsis-Transfer - Local1-Transfer Feature Extract/best - tauc - Sepsis-Transfer - MLP - lr_0.003 - CEL.pt'
'./checkpoint/2021.12.10.t1 - Sepsis - MLP - Sepsis-Transfer - Local1-Transfer Feature Extract/best - tauc - Sepsis-Transfer - MLP - lr_0.003 - CEL.pt'
# validation_set = TensorDataset(torch.FloatTensor(X_test_), torch.FloatTensor(y_test_))
# test_loader = DataLoader(validation_set, batch_size=139, shuffle=False)
# checkpoint_path = f'./checkpoint/{project_folder}/best - tauc - Sepsis-original - MLP3 - lr_0.003 - CEL.pt'
# checkpoint = torch.load(checkpoint_path, map_location=torch.device(device))
# model = model_create()
# model.load_state_dict(checkpoint['model_state_dict'])
# model.to('cpu')
# with torch.no_grad():
#     for i, (text, label) in enumerate(test_loader, start=1):
#         output = model(text.to('cpu'))
#         label = label
#     acc = metrics.accuracy_score(output>0.5, label)
#     fpr, tpr, thresholds = metrics.roc_curve(label, output, pos_label=1)
#     auc = metrics.auc(fpr, tpr)
#     print("///-------original model-------///")
#     print("Accuracy:", round(acc,5), "\nAUC:", round(auc,5))

# # Dataset Scale
# # train  0:  385 1: 31
# # valid 0:  129 1: 10

# # Test 結果
# # 沒有初始化model weight
# # Accuracy: 0.94964 
# # AUC: 0.94109

# # 有初始化model weight
# # Accuracy: 0.92806 
# # AUC: 0.89147
# Out:
# './checkpoint/2021.12.10.t1 - Sepsis - MLP - Sepsis-Transfer - Local1-Transfer Feature Extract/best - tauc - Sepsis-Transfer - MLP - lr_0.003 - CEL.pt'
