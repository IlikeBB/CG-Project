# %%
import nibabel as nib
import numpy as np, os
import SimpleITK as sitk
import pydicom
# nii data is0001 is0002 is0003
# path ='../is0001-is0154_mask_and_image/'
path = '../temp/is0001/MR/'
data_list = sorted(os.listdir(path))
print(data_list)
# Out:
# ['PRS00655', 'PRS00656', 'PRS00657', 'PRS00658', 'PRS00659', 'PRS00660', 'PRS00661', 'PRS00662', 'PRS00663', 'PRS00664', 'PRS00665', 'PRS00666', 'PRS00667', 'SRS00000', 'SRS00001', 'SRS00002', 'SRS00003', 'SRS00004', 'SRS00005', 'SRS00006', 'SRS00007', 'SRS00008', 'SRS00009', 'SRS00010', 'SRS00011', 'SRS00012']

# %%
import matplotlib.pyplot as plt
def plot_slices(num_rows, num_columns, width, height, data):
    data = np.transpose(data)
    data = np.reshape(data, (num_rows, num_columns, width, height))
    rows_data, columns_data = data.shape[0], data.shape[1]
    heights = [slc[0].shape[0] for slc in data]
    widths = [slc.shape[1] for slc in data[0]]
    fig_width = 12.0
    fig_height = fig_width * sum(heights) / sum(widths)
    f, axarr = plt.subplots(rows_data,columns_data,figsize=(fig_width, fig_height),
                            gridspec_kw={"height_ratios": heights},)
    for i in range(rows_data):
        for j in range(columns_data):
            axarr[i, j].imshow(data[i][j], cmap = "gray")
            axarr[i, j].axis("off")
    plt.subplots_adjust(wspace=0, hspace=0, left=0, right=1, bottom=0, top=1)
    plt.show()

# %%
# load nii and show
for i in range(0,5,2):
#     load nii start
    load = path +data_list[i]
#     image = nib.load(load)
#     image = image.get_fdata()
#     load nii end
    print(data_list[i]+"↓")
#     plot_slices(3, 6, image.shape[0], image.shape[1], image[:,:, :18])
# Out:
# is0001o.nii.gz↓
# is0002o.nii.gz↓
# is0003o.nii.gz↓
# is0004o.nii.gz↓
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-b5fa96494472> in <module>
#       7 #     load nii end
#       8     print(data_list[i]+"↓")
# ----> 9     plot_slices(3, 6, image.shape[0], image.shape[1], image[:,:, :18])
#      10
#
# <ipython-input-14-8bf3a32afdbc> in plot_slices(num_rows, num_columns, width, height, data)
#       2 def plot_slices(num_rows, num_columns, width, height, data):
#       3     data = np.transpose(data)
# ----> 4     data = np.reshape(data, (num_rows, num_columns, width, height))
#       5     rows_data, columns_data = data.shape[0], data.shape[1]
#       6     heights = [slc[0].shape[0] for slc in data]
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# ~/anaconda3/envs/er_tf2/lib/python3.7/site-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     299            [5, 6]])
#     300     """
# --> 301     return _wrapfunc(a, 'reshape', newshape, order=order)
#     302
#     303
#
# ~/anaconda3/envs/er_tf2/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      59
#      60     try:
# ---> 61         return bound(*args, **kwds)
#      62     except TypeError:
#      63         # A TypeError occurs if the object does have such a method in its
#
# ValueError: cannot reshape array of size 5308416 into shape (3,6,384,384)
